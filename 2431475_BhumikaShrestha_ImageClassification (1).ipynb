# %% [markdown]
# # Image Classification
# ### Intel Scene Classification | CNN from Scratch + Transfer Learning

# %%
# ── Imports ──────────────────────────────────────────────────────
import os, random, time
from collections import defaultdict

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from PIL import Image, UnidentifiedImageError

from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay, accuracy_score, f1_score

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import Input
from tensorflow.keras.layers import (Conv2D, MaxPooling2D, Dense, Flatten,
    Dropout, BatchNormalization, GlobalAveragePooling2D)
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras import regularizers

SEED = 42
random.seed(SEED); np.random.seed(SEED); tf.random.set_seed(SEED)

print(f"TensorFlow  : {tf.__version__}")
print(f"GPU devices : {tf.config.list_physical_devices('GPU')}")
# Out:
# TensorFlow  : 2.20.0
# GPU devices : [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ## Dataset Setup

# %%
# ── Mount Google Drive ───────────────────────────────────────────
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
BASE_DIR  = '/content/drive/MyDrive/AI and ML/Data/Scene Classification'
train_dir = os.path.join(BASE_DIR, '/content/drive/MyDrive/AI and ML/Data/Scene Classification/train')
test_dir  = os.path.join(BASE_DIR, '/content/drive/MyDrive/AI and ML/Data/Scene Classification/test')

status = "Found" if os.path.exists(train_dir) and os.path.exists(test_dir) else " Not found"
print(f"Folders: {status}")

class_list = sorted(os.listdir(train_dir))
print(f"Classes ({len(class_list)}): {class_list}")
# Out:
# Folders: Found
# Classes (6): ['buildings', 'forest', 'glacier', 'mountain', 'sea', 'street']

# %% [markdown]
# ---
# # Part A — CNNs from Scratch
# ## 1. Data Understanding, Analysis & Cleaning

# %% [markdown]
# ### 1.1 Dataset Description
# The **Intel Scene Classification** dataset has **6 natural scene classes**: buildings, forest, glacier, mountain, sea, street. Pre-split into ~14k train and ~3k test images.

# %%
def count_per_class(root, plot=True, title='Distribution'):
    """Count images per class and optionally plot."""
    counts = {}
    for cls in sorted(os.listdir(root)):
        p = os.path.join(root, cls)
        if os.path.isdir(p):
            counts[cls] = len([f for f in os.listdir(p)
                               if f.lower().endswith(('.jpg','.jpeg','.png'))])
    total = sum(counts.values())
    print(f"Total: {total}")
    for c, n in counts.items():
        print(f"  {c:<12}: {n:>5}  ({100*n/total:.1f}%)")
    if plot:
        fig, ax = plt.subplots(figsize=(9, 4))
        palette = plt.cm.Set2(range(len(counts)))
        bars = ax.bar(counts.keys(), counts.values(), color=palette, edgecolor='black')
        for b, n in zip(bars, counts.values()):
            ax.text(b.get_x()+b.get_width()/2, b.get_height()+30, str(n),
                    ha='center', va='bottom', fontsize=10)
        ax.set_title(title, fontsize=14, fontweight='bold')
        ax.set_xlabel('Class'); ax.set_ylabel('Images')
        ax.grid(axis='y', linestyle='--', alpha=0.5)
        plt.tight_layout(); plt.show()
    return counts

print("=== Training Set ===")
train_counts = count_per_class(train_dir, title='Class Distribution — Train')
print("\n=== Test Set ===")
test_counts  = count_per_class(test_dir,  plot=False)
# Out:
# === Training Set ===
# Total: 14008
#   buildings   :  2184  (15.6%)
#   forest      :  2264  (16.2%)
#   glacier     :  2397  (17.1%)
#   mountain    :  2521  (18.0%)
#   sea         :  2267  (16.2%)
#   street      :  2375  (17.0%)
# === Test Set ===
# Total: 3000
#   buildings   :   437  (14.6%)
#   forest      :   474  (15.8%)
#   glacier     :   553  (18.4%)
#   mountain    :   525  (17.5%)
#   sea         :   510  (17.0%)
#   street      :   501  (16.7%)

# %% [markdown]
# ### 1.2 Train / Validation Split
# 80% training / 20% validation via `image_dataset_from_directory`. Test set kept unseen for final evaluation.

# %%
def remove_bad_images(root, verbose=False):
    removed = 0
    for cls in sorted(os.listdir(root)):
        cls_p = os.path.join(root, cls)
        if not os.path.isdir(cls_p): continue
        for fname in os.listdir(cls_p):
            fpath = os.path.join(cls_p, fname)
            if not os.path.isfile(fpath): continue
            try:
                with Image.open(fpath) as img: img.verify()
            except (IOError, UnidentifiedImageError):
                os.remove(fpath); removed += 1
                if verbose: print(f"Removed: {fpath}")
    print(f"Corrupted removed: {removed}")

remove_bad_images(train_dir)
remove_bad_images(test_dir)
# Out:
# Corrupted removed: 0
# Corrupted removed: 0

# %%
IMG_SIZE   = (150, 150)
BATCH_SIZE = 32

train_raw = tf.keras.utils.image_dataset_from_directory(
    train_dir, validation_split=0.2, subset='training',
    seed=SEED, image_size=IMG_SIZE, batch_size=BATCH_SIZE)

val_raw = tf.keras.utils.image_dataset_from_directory(
    train_dir, validation_split=0.2, subset='validation',
    seed=SEED, image_size=IMG_SIZE, batch_size=BATCH_SIZE)

CLASS_NAMES = train_raw.class_names
NUM_CLASSES = len(CLASS_NAMES)
print(f"Classes ({NUM_CLASSES}): {CLASS_NAMES}")

norm = lambda x, y: (tf.cast(x, tf.float32) / 255.0, y)

train_ds = (train_raw.map(norm, num_parallel_calls=tf.data.AUTOTUNE)
            .cache().shuffle(1000, seed=SEED).prefetch(tf.data.AUTOTUNE))

val_ds = (val_raw.map(norm, num_parallel_calls=tf.data.AUTOTUNE)
          .cache().prefetch(tf.data.AUTOTUNE))
# Out:
# Found 14008 files belonging to 6 classes.
# Using 11207 files for training.
# Found 14008 files belonging to 6 classes.
# Using 2801 files for validation.
# Classes (6): ['buildings', 'forest', 'glacier', 'mountain', 'sea', 'street']

# %%
# Collect 3 sample images per class for visualisation
samples = {c: [] for c in CLASS_NAMES}
for imgs, lbls in train_ds.unbatch().take(2000):
    name = CLASS_NAMES[int(lbls.numpy())]
    if len(samples[name]) < 3:
        samples[name].append(imgs.numpy())
    if all(len(v) == 3 for v in samples.values()):
        break

fig, axes = plt.subplots(3, 6, figsize=(16, 8))
fig.suptitle('Sample Images — 3 per Class', fontsize=14, fontweight='bold')
for col, cls in enumerate(CLASS_NAMES):
    for row in range(3):
        ax = axes[row, col]
        ax.imshow(samples[cls][row]); ax.axis('off')
        if row == 0: ax.set_title(cls.capitalize(), fontsize=11, fontweight='bold')
plt.tight_layout(); plt.show()

# %%
# Data augmentation pipeline
augment_layer = keras.Sequential([
    keras.layers.RandomFlip('horizontal'),
    keras.layers.RandomRotation(0.15),
    keras.layers.RandomZoom(0.2),
    keras.layers.RandomTranslation(0.1, 0.1),
    keras.layers.RandomContrast(0.2),
], name='augmentation')

# Show augmented examples for each class
aug_ops = [
    (keras.layers.RandomRotation(0.2),        "Rotation"),
    (keras.layers.RandomZoom(0.3),             "Zoom"),
    (keras.layers.RandomTranslation(0.2, 0.2), "Translation"),
    (keras.layers.RandomContrast(0.4),         "Contrast"),
]

for cls_name in CLASS_NAMES:
    orig = np.array(random.choice(samples[cls_name]))
    fig, axes = plt.subplots(1, 5, figsize=(12, 3))
    axes[0].imshow(orig); axes[0].set_title("Original"); axes[0].axis('off')
    for i, (op, name) in enumerate(aug_ops, 1):
        t = tf.expand_dims(orig, 0)
        out = tf.clip_by_value(op(t, training=True)[0], 0.0, 1.0)
        axes[i].imshow(out.numpy()); axes[i].set_title(name); axes[i].axis('off')
    fig.suptitle(f"Augmentations — '{cls_name}'", fontsize=13)
    plt.tight_layout(); plt.show()

# %%
print('Preprocessing Summary')
print('=' * 45)
print(f'  Resize        : {IMG_SIZE[0]}×{IMG_SIZE[1]} px')
print(f'  Normalisation : ÷ 255  →  [0.0, 1.0]')
print(f'  Batch size    : {BATCH_SIZE}')
print(f'  Split         : 80% train / 20% validation')
print(f'  Augmentation  : Flip, Rotation, Zoom, Translation, Contrast')
print(f'  Classes       : {CLASS_NAMES}')
# Out:
# Preprocessing Summary
# =============================================
#   Resize        : 150×150 px
#   Normalisation : ÷ 255  →  [0.0, 1.0]
#   Batch size    : 32
#   Split         : 80% train / 20% validation
#   Augmentation  : Flip, Rotation, Zoom, Translation, Contrast
#   Classes       : ['buildings', 'forest', 'glacier', 'mountain', 'sea', 'street']

# %% [markdown]
# ---
# ## 2. Baseline CNN (Functional API)
# 3 Conv→Pool blocks + 3 Dense layers + Softmax output.

# %%
def build_baseline(input_shape=(150,150,3), n_classes=6):
    """Baseline CNN built with the Functional API."""
    inp = Input(shape=input_shape)

    # Conv Block 1
    x = Conv2D(32, (3,3), activation='relu', padding='same')(inp)
    x = MaxPooling2D((2,2))(x)

    # Conv Block 2
    x = Conv2D(64, (3,3), activation='relu', padding='same')(x)
    x = MaxPooling2D((2,2))(x)

    # Conv Block 3
    x = Conv2D(128, (3,3), activation='relu', padding='same')(x)
    x = MaxPooling2D((2,2))(x)

    # Classification head
    x = Flatten()(x)
    x = Dense(512, activation='relu')(x)
    x = Dense(256, activation='relu')(x)
    x = Dense(128, activation='relu')(x)
    out = Dense(n_classes, activation='softmax')(x)

    return Model(inp, out, name='Baseline_CNN')

baseline_model = build_baseline((*IMG_SIZE, 3), NUM_CLASSES)
baseline_model.summary()
# Out:
# Model: "Baseline_CNN"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 150, 150, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 150, 150, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 75, 75, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 75, 75, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 37, 37, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 37, 37, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 18, 18, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 41472)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │    21,234,176 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 6)              │           774 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 21,492,422 (81.99 MB)
#  Trainable params: 21,492,422 (81.99 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
aug_train_ds = train_ds.map(
    lambda x, y: (augment_layer(x, training=True), y),
    num_parallel_calls=tf.data.AUTOTUNE)

baseline_model.compile(
    optimizer=Adam(1e-3),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy'])

base_cbs = [
    EarlyStopping(monitor='val_accuracy', patience=5, restore_best_weights=True, verbose=1),
    ModelCheckpoint('best_baseline.keras', monitor='val_accuracy', save_best_only=True, verbose=0)
]

print("Training Baseline CNN …")
t0 = time.time()
baseline_hist = baseline_model.fit(
    aug_train_ds, validation_data=val_ds,
    epochs=25, callbacks=base_cbs, verbose=1)
base_time = time.time() - t0
print(f"Done  — {base_time:.0f}s  ({base_time/60:.1f} min)")
# Out:
# Training Baseline CNN …
# Epoch 1/25
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 91s 238ms/step - accuracy: 0.5282 - loss: 1.1900 - val_accuracy: 0.5159 - val_loss: 1.3102
# Epoch 2/25
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 73s 207ms/step - accuracy: 0.6167 - loss: 0.9912 - val_accuracy: 0.5980 - val_loss: 1.0933
# Epoch 3/25
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 73s 207ms/step - accuracy: 0.6727 - loss: 0.8751 - val_accuracy: 0.6855 - val_loss: 0.8626
# Epoch 4/25
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 72s 203ms/step - accuracy: 0.6964 - loss: 0.8148 - val_accuracy: 0.6608 - val_loss: 0.8971
# Epoch 5/25
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 83s 205ms/step - accuracy: 0.7187 - loss: 0.7650 - val_accuracy: 0.7151 - val_loss: 0.7774
# Epoch 6/25
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 81s 203ms/step - accuracy: 0.7347 - loss: 0.7305 - val_accuracy: 0.7005 - val_loss: 0.8284
# Epoch 7/25
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 84s 207ms/step - accuracy: 0.7510 - loss: 0.6872 - val_accuracy: 0.7715 - val_loss: 0.6291
# Epoch 8/25
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 72s 203ms/step - accuracy: 0.7626 - loss: 0.6483 - val_accuracy: 0.7526 - val_loss: 0.7287
# Epoch 9/25
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 71s 201ms/step - accuracy: 0.7599 - loss: 0.6498 - val_accuracy: 0.7280 - val_loss: 0.7431
# Epoch 10/25
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 82s 200ms/step - accuracy: 0.7762 - loss: 0.6086 - val_accuracy: 0.7429 - val_loss: 0.7311
# Epoch 11/25
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 90s 224ms/step - accuracy: 0.7828 - loss: 0.5937 - val_accuracy: 0.7787 - val_loss: 0.6357
# Epoch 12/25
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 70s 198ms/step - accuracy: 0.7940 - loss: 0.5700 - val_accuracy: 0.7783 - val_loss: 0.6516
# Epoch 13/25
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 78s 221ms/step - accuracy: 0.7940 - loss: 0.5615 - val_accuracy: 0.7790 - val_loss: 0.6411
# Epoch 14/25
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 73s 206ms/step - accuracy: 0.8027 - loss: 0.5426 - val_accuracy: 0.7940 - val_loss: 0.6051
# Epoch 15/25
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 81s 202ms/step - accuracy: 0.8032 - loss: 0.5351 - val_accuracy: 0.7483 - val_loss: 0.6973
# Epoch 16/25
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 72s 205ms/step - accuracy: 0.8153 - loss: 0.5084 - val_accuracy: 0.7836 - val_loss: 0.6056
# Epoch 17/25
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 82s 204ms/step - accuracy: 0.8147 - loss: 0.5084 - val_accuracy: 0.7783 - val_loss: 0.6101
# Epoch 18/25
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 82s 203ms/step - accuracy: 0.8193 - loss: 0.5028 - val_accuracy: 0.8029 - val_loss: 0.5605
# Epoch 19/25
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 82s 204ms/step - accuracy: 0.8234 - loss: 0.4798 - val_accuracy: 0.7961 - val_loss: 0.5936
# Epoch 20/25
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 72s 205ms/step - accuracy: 0.8215 - loss: 0.4854 - val_accuracy: 0.7747 - val_loss: 0.6447
# Epoch 21/25
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 82s 205ms/step - accuracy: 0.8333 - loss: 0.4596 - val_accuracy: 0.7369 - val_loss: 0.7773
# Epoch 22/25
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 81s 201ms/step - accuracy: 0.8275 - loss: 0.4583 - val_accuracy: 0.7947 - val_loss: 0.6073
# Epoch 23/25
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 83s 206ms/step - accuracy: 0.8385 - loss: 0.4438 - val_accuracy: 0.7919 - val_loss: 0.5694
# Epoch 23: early stopping
# Restoring model weights from the end of the best epoch: 18.
# Done  — 1806s  (30.1 min)

# %%
def plot_curves(history, title='Training History'):
    """Plot accuracy and loss side-by-side."""
    fig, (a1, a2) = plt.subplots(1, 2, figsize=(14, 5))
    fig.suptitle(title, fontsize=14, fontweight='bold')

    a1.plot(history.history['accuracy'],     label='Train', color='royalblue',  lw=2, marker='o', ms=4)
    a1.plot(history.history['val_accuracy'], label='Val',   color='darkorange', lw=2, marker='s', ms=4)
    a1.set_title('Accuracy'); a1.set_xlabel('Epoch'); a1.set_ylabel('Accuracy')
    a1.set_ylim(0, 1.05); a1.legend(); a1.grid(True, ls='--', alpha=0.5)

    a2.plot(history.history['loss'],     label='Train', color='crimson', lw=2, marker='o', ms=4)
    a2.plot(history.history['val_loss'], label='Val',   color='teal',    lw=2, marker='s', ms=4)
    a2.set_title('Loss'); a2.set_xlabel('Epoch'); a2.set_ylabel('Loss')
    a2.legend(); a2.grid(True, ls='--', alpha=0.5)
    plt.tight_layout(); plt.show()

plot_curves(baseline_hist, 'Baseline CNN — Training History')

# %%
def run_evaluation(model, ds, class_names, title='Evaluation'):
    y_true, y_pred = [], []
    for imgs, lbls in ds:
        preds = model.predict(imgs, verbose=0)
        y_true.extend(lbls.numpy())
        y_pred.extend(np.argmax(preds, axis=1))
    y_true, y_pred = np.array(y_true), np.array(y_pred)

    print(f"\n=== {title} ===")
    print(classification_report(y_true, y_pred, target_names=class_names))

    cm = confusion_matrix(y_true, y_pred)
    fig, ax = plt.subplots(figsize=(8,6))
    ConfusionMatrixDisplay(cm, display_labels=class_names).plot(
        ax=ax, cmap='Blues', xticks_rotation=45, colorbar=False)
    ax.set_title(f'Confusion Matrix — {title}', fontsize=13, fontweight='bold')
    plt.tight_layout(); plt.show()
    return y_true, y_pred

base_yt, base_yp = run_evaluation(baseline_model, val_ds, CLASS_NAMES, 'Baseline CNN (Val)')
# Out:
# === Baseline CNN (Val) ===
#               precision    recall  f1-score   support
#
#    buildings       0.77      0.77      0.77       429
#       forest       0.93      0.95      0.94       435
#      glacier       0.73      0.77      0.75       474
#     mountain       0.75      0.75      0.75       515
#          sea       0.82      0.76      0.79       475
#       street       0.84      0.84      0.84       473
#
#     accuracy                           0.80      2801
#    macro avg       0.81      0.81      0.80      2801
# weighted avg       0.80      0.80      0.80      2801

# %%
# Inference samples
imgs_b, lbls_b = next(iter(val_ds))
preds_b = np.argmax(baseline_model.predict(imgs_b, verbose=0), axis=1)

fig, axes = plt.subplots(2, 6, figsize=(18, 6))
fig.suptitle('Baseline CNN — Validation Inference', fontsize=14, fontweight='bold')
for i, ax in enumerate(axes.flat):
    if i >= len(imgs_b): ax.axis('off'); continue
    ax.imshow(imgs_b[i].numpy()); ax.axis('off')
    tl = CLASS_NAMES[int(lbls_b[i].numpy())]; pl = CLASS_NAMES[preds_b[i]]
    ax.set_title(f'T:{tl}\nP:{pl}', fontsize=8, color='green' if tl==pl else 'red')
plt.tight_layout(); plt.show()
print("Green = correct  |  Red = incorrect")
# Out:
# Green = correct  |  Red = incorrect

# %% [markdown]
# ### Baseline Observations
# The baseline converges reasonably well. `mountain`↔`glacier` and `buildings`↔`street` are the most confused pairs due to visual similarity. Mild overfitting visible without explicit regularisation.

# %% [markdown]
# ---
# ## 3. Deeper CNN with Regularisation
# Doubles Conv layers, adds BatchNorm, Dropout, L2 to reduce overfitting.

# %%
def build_deeper(input_shape=(150,150,3), n_classes=6, l2=1e-3):
    """Deeper Functional-API CNN with BatchNorm + Dropout + L2."""
    reg = regularizers.l2(l2)
    inp = x = Input(shape=input_shape)

    for filters, drop in [(32, 0.25), (64, 0.30), (128, 0.35), (256, 0.40)]:
        x = Conv2D(filters, (3,3), padding='same', activation='relu', kernel_regularizer=reg)(x)
        x = BatchNormalization()(x)
        x = Conv2D(filters, (3,3), padding='same', activation='relu', kernel_regularizer=reg)(x)
        x = BatchNormalization()(x)
        x = MaxPooling2D((2,2))(x)
        x = Dropout(drop)(x)

    x = GlobalAveragePooling2D()(x)
    for units, drop in [(512, 0.40), (256, 0.30), (128, 0.25)]:
        x = Dense(units, activation='relu', kernel_regularizer=reg)(x)
        x = BatchNormalization()(x)
        x = Dropout(drop)(x)

    out = Dense(n_classes, activation='softmax')(x)
    return Model(inp, out, name='Deeper_CNN')

deeper_model = build_deeper((*IMG_SIZE, 3), NUM_CLASSES)
deeper_model.summary()
# Out:
# Model: "Deeper_CNN"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)      │ (None, 150, 150, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 150, 150, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 150, 150, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 150, 150, 32)   │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 150, 150, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 75, 75, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 75, 75, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 75, 75, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 75, 75, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 75, 75, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 75, 75, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 37, 37, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 37, 37, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 37, 37, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 37, 37, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_8 (Conv2D)               │ (None, 37, 37, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 37, 37, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 18, 18, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 18, 18, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_9 (Conv2D)               │ (None, 18, 18, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 18, 18, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_10 (Conv2D)              │ (None, 18, 18, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 18, 18, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_6 (MaxPooling2D)  │ (None, 9, 9, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 9, 9, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 256)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 512)            │       131,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_8           │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_9           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_10          │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 6)              │           774 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,476,262 (5.63 MB)
#  Trainable params: 1,472,550 (5.62 MB)
#  Non-trainable params: 3,712 (14.50 KB)

# %% [markdown]
# ### Deeper Model Analysis
# - **8 Conv2D** layers learn richer hierarchical features vs 3 in baseline.
# - **BatchNorm** stabilises activations, reduces internal covariate shift.
# - **Dropout (0.25→0.40)** progressively increases in deeper blocks.
# - **GlobalAveragePooling** reduces params vs Flatten.

# %%
deeper_model.compile(
    optimizer=Adam(5e-4),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy'])

deep_cbs = [
    EarlyStopping(monitor='val_accuracy', patience=6, restore_best_weights=True, verbose=1),
    ModelCheckpoint('best_deeper_adam.keras', monitor='val_accuracy', save_best_only=True, verbose=0),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-6, verbose=1)
]

print("Training Deeper CNN (Adam) …")
t0 = time.time()
hist_adam = deeper_model.fit(
    aug_train_ds, validation_data=val_ds,
    epochs=40, callbacks=deep_cbs, verbose=1)
adam_time = time.time() - t0
print(f"Done — {adam_time:.0f}s  ({adam_time/60:.1f} min)")

plot_curves(hist_adam, 'Deeper CNN (Adam) — Training History')
deep_yt, deep_yp = run_evaluation(deeper_model, val_ds, CLASS_NAMES, 'Deeper CNN Adam (Val)')
# Out:
# Training Deeper CNN (Adam) …
# Epoch 1/40
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 130s 294ms/step - accuracy: 0.4555 - loss: 3.0579 - val_accuracy: 0.2803 - val_loss: 3.7159 - learning_rate: 5.0000e-04
# Epoch 2/40
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 81s 230ms/step - accuracy: 0.5610 - loss: 2.6577 - val_accuracy: 0.5373 - val_loss: 2.6650 - learning_rate: 5.0000e-04
# Epoch 3/40
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 81s 230ms/step - accuracy: 0.6169 - loss: 2.3837 - val_accuracy: 0.6041 - val_loss: 2.3090 - learning_rate: 5.0000e-04
# Epoch 4/40
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 81s 227ms/step - accuracy: 0.6474 - loss: 2.1496 - val_accuracy: 0.5755 - val_loss: 2.3868 - learning_rate: 5.0000e-04
# Epoch 5/40
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 83s 231ms/step - accuracy: 0.6818 - loss: 1.9253 - val_accuracy: 0.6487 - val_loss: 1.9301 - learning_rate: 5.0000e-04
# Epoch 6/40
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 81s 228ms/step - accuracy: 0.6988 - loss: 1.7386 - val_accuracy: 0.7333 - val_loss: 1.5909 - learning_rate: 5.0000e-04
# Epoch 7/40
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 81s 230ms/step - accuracy: 0.7174 - loss: 1.5664 - val_accuracy: 0.6637 - val_loss: 1.7129 - learning_rate: 5.0000e-04
# Epoch 8/40
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 81s 227ms/step - accuracy: 0.7227 - loss: 1.4467 - val_accuracy: 0.6765 - val_loss: 1.5006 - learning_rate: 5.0000e-04
# Epoch 9/40
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 82s 226ms/step - accuracy: 0.7390 - loss: 1.3154 - val_accuracy: 0.7197 - val_loss: 1.3563 - learning_rate: 5.0000e-04
# Epoch 10/40
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 80s 227ms/step - accuracy: 0.7426 - loss: 1.2298 - val_accuracy: 0.6044 - val_loss: 1.8816 - learning_rate: 5.0000e-04
# Epoch 11/40
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 81s 229ms/step - accuracy: 0.7485 - loss: 1.1534 - val_accuracy: 0.6423 - val_loss: 1.6436 - learning_rate: 5.0000e-04
# Epoch 12/40
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 80s 228ms/step - accuracy: 0.7571 - loss: 1.0804 - val_accuracy: 0.6937 - val_loss: 1.2025 - learning_rate: 5.0000e-04
# Epoch 12: early stopping
# Restoring model weights from the end of the best epoch: 6.
# Done — 1023s  (17.1 min)
# === Deeper CNN Adam (Val) ===
#               precision    recall  f1-score   support
#
#    buildings       0.75      0.63      0.68       429
#       forest       0.90      0.94      0.92       435
#      glacier       0.67      0.70      0.69       474
#     mountain       0.61      0.70      0.65       515
#          sea       0.67      0.74      0.70       475
#       street       0.87      0.70      0.77       473
#
#     accuracy                           0.73      2801
#    macro avg       0.75      0.73      0.74      2801
# weighted avg       0.74      0.73      0.73      2801

# %% [markdown]
# ---
# ## 4. Experimentation & Comparative Analysis
# ### 4.1 Baseline vs Deeper

# %%
fig, (a1, a2) = plt.subplots(1, 2, figsize=(14, 5))
fig.suptitle('Baseline vs Deeper CNN', fontsize=14, fontweight='bold')

for ax, metric in zip([a1, a2], ['accuracy', 'loss']):
    ax.plot(baseline_hist.history[metric],          label='Baseline — Train', color='royalblue')
    ax.plot(baseline_hist.history[f'val_{metric}'], label='Baseline — Val',   color='royalblue',  ls='--')
    ax.plot(hist_adam.history[metric],              label='Deeper — Train',   color='darkorange')
    ax.plot(hist_adam.history[f'val_{metric}'],     label='Deeper — Val',     color='darkorange', ls='--')
    ax.set_title(metric.capitalize()); ax.set_xlabel('Epoch')
    ax.legend(fontsize=9); ax.grid(True, alpha=0.4)
    if metric == 'accuracy': ax.set_ylim(0, 1.05)
plt.tight_layout(); plt.show()

print(f"Best Val Accuracy  |  Baseline: {max(baseline_hist.history['val_accuracy']):.4f}"
      f"  |  Deeper: {max(hist_adam.history['val_accuracy']):.4f}")
# Out:
# Best Val Accuracy  |  Baseline: 0.8029  |  Deeper: 0.7333

# %% [markdown]
# ### 4.2 Computational Efficiency

# %%
bp = baseline_model.count_params(); dp = deeper_model.count_params()
print(f"Baseline params : {bp:,}")
print(f"Deeper   params : {dp:,}  ({dp/bp:.1f}×)")
print(f"Baseline time   : {base_time:.0f}s")
print(f"Deeper   time   : {adam_time:.0f}s  ({adam_time/base_time:.1f}×)")

fig, (a1, a2) = plt.subplots(1, 2, figsize=(10, 4))
fig.suptitle('Computational Efficiency', fontsize=13, fontweight='bold')
a1.bar(['Baseline','Deeper'], [bp, dp], color=['steelblue','darkorange'], edgecolor='black')
a1.set_title('Parameters'); a1.yaxis.set_major_formatter(plt.FuncFormatter(lambda x,_: f'{x/1e6:.1f}M'))
a2.bar(['Baseline','Deeper'], [base_time, adam_time], color=['steelblue','darkorange'], edgecolor='black')
a2.set_title('Training Time (s)')
plt.tight_layout(); plt.show()
# Out:
# Baseline params : 21,492,422
# Deeper   params : 1,476,262  (0.1×)
# Baseline time   : 1806s
# Deeper   time   : 1023s  (0.6×)

# %% [markdown]
# ### 4.3 Optimizer Comparison — SGD vs Adam

# %%
sgd_model = build_deeper((*IMG_SIZE, 3), NUM_CLASSES)
sgd_model.compile(
    optimizer=SGD(5e-3, momentum=0.9, nesterov=True),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy'])

sgd_cbs = [
    EarlyStopping(monitor='val_accuracy', patience=6, restore_best_weights=True, verbose=1),
    ModelCheckpoint('best_deeper_sgd.keras', monitor='val_accuracy', save_best_only=True, verbose=0)
]

print("Training Deeper CNN (SGD+Nesterov) …")
t0 = time.time()
hist_sgd = sgd_model.fit(
    aug_train_ds, validation_data=val_ds,
    epochs=40, callbacks=sgd_cbs, verbose=1)
sgd_time = time.time() - t0
print(f"Done — {sgd_time:.0f}s  ({sgd_time/60:.1f} min)")
# Out:
# Training Deeper CNN (SGD+Nesterov) …
# Epoch 1/40
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 110s 269ms/step - accuracy: 0.4698 - loss: 3.0406 - val_accuracy: 0.3102 - val_loss: 3.3524
# Epoch 2/40
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 118s 232ms/step - accuracy: 0.5722 - loss: 2.6473 - val_accuracy: 0.4384 - val_loss: 2.9181
# Epoch 3/40
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 80s 228ms/step - accuracy: 0.6160 - loss: 2.4696 - val_accuracy: 0.4738 - val_loss: 2.6854
# Epoch 4/40
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 82s 232ms/step - accuracy: 0.6431 - loss: 2.3164 - val_accuracy: 0.6148 - val_loss: 2.3108
# Epoch 5/40
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 79s 225ms/step - accuracy: 0.6685 - loss: 2.1806 - val_accuracy: 0.5216 - val_loss: 2.6193
# Epoch 6/40
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 81s 230ms/step - accuracy: 0.6803 - loss: 2.0604 - val_accuracy: 0.6812 - val_loss: 2.0593
# Epoch 7/40
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 81s 230ms/step - accuracy: 0.7002 - loss: 1.9516 - val_accuracy: 0.7119 - val_loss: 1.9241
# Epoch 8/40
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 82s 234ms/step - accuracy: 0.7082 - loss: 1.8606 - val_accuracy: 0.6773 - val_loss: 1.9345
# Epoch 9/40
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 80s 226ms/step - accuracy: 0.7247 - loss: 1.7571 - val_accuracy: 0.6873 - val_loss: 1.8199
# Epoch 10/40
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 81s 229ms/step - accuracy: 0.7302 - loss: 1.6815 - val_accuracy: 0.7715 - val_loss: 1.5680
# Epoch 11/40
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 79s 225ms/step - accuracy: 0.7462 - loss: 1.5915 - val_accuracy: 0.5005 - val_loss: 3.1219
# Epoch 12/40
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 79s 225ms/step - accuracy: 0.7498 - loss: 1.5297 - val_accuracy: 0.6876 - val_loss: 1.6691
# Epoch 13/40
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 82s 225ms/step - accuracy: 0.7572 - loss: 1.4623 - val_accuracy: 0.7090 - val_loss: 1.5526
# Epoch 14/40
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 85s 233ms/step - accuracy: 0.7709 - loss: 1.3893 - val_accuracy: 0.6755 - val_loss: 1.6281
# Epoch 15/40
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 79s 224ms/step - accuracy: 0.7677 - loss: 1.3551 - val_accuracy: 0.7497 - val_loss: 1.3708
# Epoch 16/40
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 81s 231ms/step - accuracy: 0.7645 - loss: 1.3068 - val_accuracy: 0.7612 - val_loss: 1.3004
# Epoch 16: early stopping
# Restoring model weights from the end of the best epoch: 10.
# Done — 1361s  (22.7 min)

# %%
fig, (a1, a2) = plt.subplots(1, 2, figsize=(14, 5))
fig.suptitle('Optimizer Comparison: Adam vs SGD', fontsize=14, fontweight='bold')
for ax, m in zip([a1,a2], ['accuracy','loss']):
    ax.plot(hist_adam.history[m],          label='Adam—Train', color='royalblue')
    ax.plot(hist_adam.history[f'val_{m}'], label='Adam—Val',   color='royalblue',  ls='--')
    ax.plot(hist_sgd.history[m],           label='SGD—Train',  color='darkorange')
    ax.plot(hist_sgd.history[f'val_{m}'],  label='SGD—Val',    color='darkorange', ls='--')
    ax.set_title(m.capitalize()); ax.set_xlabel('Epoch')
    ax.legend(fontsize=9); ax.grid(True, alpha=0.4)
    if m == 'accuracy': ax.set_ylim(0, 1.05)
plt.tight_layout(); plt.show()

print(f"Adam best val acc: {max(hist_adam.history['val_accuracy']):.4f}")
print(f"SGD  best val acc: {max(hist_sgd.history['val_accuracy']):.4f}")
print("Adam typically converges faster; SGD may match given more epochs.")

sgd_yt, sgd_yp = run_evaluation(sgd_model, val_ds, CLASS_NAMES, 'Deeper CNN SGD (Val)')
# Out:
# Adam best val acc: 0.7333
# SGD  best val acc: 0.7715
# Adam typically converges faster; SGD may match given more epochs.
#
# === Deeper CNN SGD (Val) ===
#               precision    recall  f1-score   support
#
#    buildings       0.72      0.85      0.78       429
#       forest       0.77      0.98      0.86       435
#      glacier       0.72      0.76      0.74       474
#     mountain       0.81      0.68      0.74       515
#          sea       0.76      0.78      0.77       475
#       street       0.89      0.62      0.73       473
#
#     accuracy                           0.77      2801
#    macro avg       0.78      0.78      0.77      2801
# weighted avg       0.78      0.77      0.77      2801

# %% [markdown]
# ### 4.4 Ablation Study — Effect of Dropout

# %%
def build_no_dropout(input_shape=(150,150,3), n_classes=6, l2=1e-3):
    """Same as deeper model but WITHOUT any Dropout layers."""
    reg = regularizers.l2(l2)
    inp = x = Input(shape=input_shape)
    for filters in [32, 64, 128, 256]:
        x = Conv2D(filters,(3,3),padding='same',activation='relu',kernel_regularizer=reg)(x)
        x = BatchNormalization()(x);
        x = Conv2D(filters,(3,3),padding='same',activation='relu',kernel_regularizer=reg)(x)
        x = BatchNormalization()(x)
        x = MaxPooling2D((2,2))(x)
    x = GlobalAveragePooling2D()(x)
    for units in [512, 256, 128]:
        x = Dense(units, activation='relu', kernel_regularizer=reg)(x)
        x = BatchNormalization()(x)
    out = Dense(n_classes, activation='softmax')(x)
    return Model(inp, out, name='NoDrop_CNN')

ablated_model = build_no_dropout((*IMG_SIZE, 3), NUM_CLASSES)
ablated_model.compile(optimizer=Adam(5e-4), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

print("Training Ablated Model (no Dropout) …")
hist_abl = ablated_model.fit(
    aug_train_ds, validation_data=val_ds, epochs=30,
    callbacks=[EarlyStopping(monitor='val_accuracy',patience=5,restore_best_weights=True,verbose=1)],
    verbose=1)

print(f"Deeper WITH Dropout : {max(hist_adam.history['val_accuracy']):.4f}")
print(f"Ablated  NO Dropout : {max(hist_abl.history['val_accuracy']):.4f}")
# Out:
# Training Ablated Model (no Dropout) …
# Epoch 1/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 104s 255ms/step - accuracy: 0.5588 - loss: 2.7793 - val_accuracy: 0.3277 - val_loss: 3.1351
# Epoch 2/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 125s 229ms/step - accuracy: 0.6546 - loss: 2.3900 - val_accuracy: 0.6612 - val_loss: 2.2591
# Epoch 3/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 79s 225ms/step - accuracy: 0.6889 - loss: 2.1255 - val_accuracy: 0.6519 - val_loss: 2.2365
# Epoch 4/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 83s 228ms/step - accuracy: 0.7046 - loss: 1.8950 - val_accuracy: 0.5162 - val_loss: 2.7700
# Epoch 5/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 80s 226ms/step - accuracy: 0.7295 - loss: 1.6613 - val_accuracy: 0.7344 - val_loss: 1.5564
# Epoch 6/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 81s 230ms/step - accuracy: 0.7439 - loss: 1.4724 - val_accuracy: 0.7251 - val_loss: 1.4552
# Epoch 7/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 79s 225ms/step - accuracy: 0.7550 - loss: 1.3177 - val_accuracy: 0.6473 - val_loss: 1.8710
# Epoch 8/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 82s 232ms/step - accuracy: 0.7636 - loss: 1.1953 - val_accuracy: 0.5859 - val_loss: 2.1174
# Epoch 9/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 80s 226ms/step - accuracy: 0.7638 - loss: 1.1144 - val_accuracy: 0.7590 - val_loss: 1.1276
# Epoch 10/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 80s 228ms/step - accuracy: 0.7735 - loss: 1.0177 - val_accuracy: 0.6441 - val_loss: 1.3780
# Epoch 11/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 80s 228ms/step - accuracy: 0.7770 - loss: 0.9590 - val_accuracy: 0.7180 - val_loss: 1.1899
# Epoch 12/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 81s 229ms/step - accuracy: 0.7924 - loss: 0.8958 - val_accuracy: 0.6958 - val_loss: 1.1811
# Epoch 13/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 81s 226ms/step - accuracy: 0.7869 - loss: 0.8858 - val_accuracy: 0.7658 - val_loss: 0.9284
# Epoch 14/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 81s 230ms/step - accuracy: 0.7954 - loss: 0.8544 - val_accuracy: 0.7665 - val_loss: 0.9001
# Epoch 15/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 80s 226ms/step - accuracy: 0.7945 - loss: 0.8298 - val_accuracy: 0.7601 - val_loss: 0.9806
# Epoch 16/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 83s 229ms/step - accuracy: 0.8059 - loss: 0.7937 - val_accuracy: 0.7597 - val_loss: 0.9491
# Epoch 17/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 81s 228ms/step - accuracy: 0.8073 - loss: 0.7898 - val_accuracy: 0.7969 - val_loss: 0.8380
# Epoch 18/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 81s 230ms/step - accuracy: 0.8090 - loss: 0.7803 - val_accuracy: 0.6362 - val_loss: 1.3224
# Epoch 19/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 80s 226ms/step - accuracy: 0.8077 - loss: 0.7703 - val_accuracy: 0.6344 - val_loss: 1.3254
# Epoch 20/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 82s 231ms/step - accuracy: 0.8105 - loss: 0.7560 - val_accuracy: 0.7258 - val_loss: 1.0308
# Epoch 21/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 80s 228ms/step - accuracy: 0.8115 - loss: 0.7442 - val_accuracy: 0.7015 - val_loss: 1.0846
# Epoch 22/30
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 82s 232ms/step - accuracy: 0.8170 - loss: 0.7289 - val_accuracy: 0.7483 - val_loss: 0.9638
# Epoch 22: early stopping
# Restoring model weights from the end of the best epoch: 17.
# Deeper WITH Dropout : 0.7333
# Ablated  NO Dropout : 0.7969

# %%
fig, (a1, a2) = plt.subplots(1, 2, figsize=(13, 4))
fig.suptitle('Ablation Study: Effect of Dropout', fontsize=13, fontweight='bold')
for ax, m in zip([a1,a2],['accuracy','loss']):
    ax.plot(hist_adam.history[m],          label='With Dropout—Train', color='royalblue')
    ax.plot(hist_adam.history[f'val_{m}'], label='With Dropout—Val',   color='royalblue',  ls='--')
    ax.plot(hist_abl.history[m],           label='No Dropout—Train',   color='firebrick')
    ax.plot(hist_abl.history[f'val_{m}'],  label='No Dropout—Val',     color='firebrick',  ls='--')
    ax.set_title(m.capitalize()); ax.set_xlabel('Epoch')
    ax.legend(fontsize=8); ax.grid(True, alpha=0.4)
    if m=='accuracy': ax.set_ylim(0,1.05)
plt.tight_layout(); plt.show()

# %% [markdown]
# **Observations:** Without Dropout, training accuracy climbs faster but the train–val gap widens (overfitting). Dropout is an effective regulariser even alongside BatchNorm and L2.

# %% [markdown]
# ### 4.5 Challenges and Observations
#
# | Challenge | Observation | Mitigation |
# |---|---|---|
# | Overfitting (baseline) | Train >> Val accuracy | Dropout, BatchNorm, L2, Augmentation |
# | Class confusion | mountain↔glacier, buildings↔street | Deeper features |
# | Slow SGD convergence | SGD needs more epochs | Nesterov + LR scheduling |
# | Training time | Deeper 2-4× slower | GPU acceleration |

# %%
print('=== Training Time Summary ===')
print(f'  Baseline CNN      : {base_time:.0f}s  ({base_time/60:.1f} min)')
print(f'  Deeper CNN (Adam) : {adam_time:.0f}s  ({adam_time/60:.1f} min)')
print(f'  Deeper CNN (SGD)  : {sgd_time:.0f}s  ({sgd_time/60:.1f} min)')
# Out:
# === Training Time Summary ===
#   Baseline CNN      : 1806s  (30.1 min)
#   Deeper CNN (Adam) : 1023s  (17.1 min)
#   Deeper CNN (SGD)  : 1361s  (22.7 min)

# %% [markdown]
# ---
# # Part B — Transfer Learning: MobileNetV2
#
# **Strategy:** (1) Feature Extraction — freeze base, train head only. (2) Fine-Tuning — unfreeze top 30 layers with tiny LR.
#
# **Why MobileNetV2?** Lightweight, efficient, accepts 150×150 input, pre-trained on natural/urban scenes (ImageNet) — ideal match for this task.

# %%
# --- MobileNetV2 expects pixel values in [-1, 1] ──────────────────────────────
preprocess_input = tf.keras.applications.mobilenet_v2.preprocess_input

# Define data_augmentation here as it is used below.
data_augmentation = tf.keras.Sequential([
    tf.keras.layers.RandomFlip("horizontal"),
    tf.keras.layers.RandomRotation(0.2),
    tf.keras.layers.RandomZoom(0.2),
])

tl_train_ds = (train_raw
               .map(lambda x, y: (preprocess_input(x), y),
                    num_parallel_calls=tf.data.AUTOTUNE)
               .map(lambda x, y: (data_augmentation(x, training=True), y),
                    num_parallel_calls=tf.data.AUTOTUNE)
               .cache().shuffle(1000, seed=SEED).prefetch(tf.data.AUTOTUNE))

tl_val_ds = (val_raw
             .map(lambda x, y: (preprocess_input(x), y),
                  num_parallel_calls=tf.data.AUTOTUNE)
             .cache().prefetch(tf.data.AUTOTUNE))

print('Transfer learning datasets ready.')
# Out:
# Transfer learning datasets ready.

# %%
import os
search_root = "/content/drive/MyDrive"
for root, dirs, files in os.walk(search_root):
    for f in files:
        if f.endswith(".zip"):
            print(os.path.join(root, f))
# Out:
# /content/drive/MyDrive/AStarSnake (1).zip
# /content/drive/MyDrive/AStarSnake.zip
# /content/drive/MyDrive/FYP/safe-journey-planner.zip

# %%
import tensorflow as tf

DATASET_PATH = "/content/drive/MyDrive/AI and ML/Data/Scene Classification/train"
IMG_SIZE = (224, 224)
BATCH_SIZE = 32
SEED = 123

train_ds = tf.keras.utils.image_dataset_from_directory(
    DATASET_PATH,
    validation_split=0.2,
    subset="training",
    seed=SEED,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE
)

val_ds = tf.keras.utils.image_dataset_from_directory(
    DATASET_PATH,
    validation_split=0.2,
    subset="validation",
    seed=SEED,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE
)

print("Classes:", train_ds.class_names)
# Out:
# Found 14008 files belonging to 6 classes.
# Using 11207 files for training.
# Found 14008 files belonging to 6 classes.
# Using 2801 files for validation.
# Classes: ['buildings', 'forest', 'glacier', 'mountain', 'sea', 'street']

# %%
import os

print(os.listdir(train_dir)[:10])
# Out:
# ['buildings', 'forest', 'glacier', 'mountain', 'sea', 'street']

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.applications import VGG16
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
DATASET_PATH = "/content/drive/MyDrive/AI and ML/Data/Scene Classification/train"

IMG_SIZE = (224, 224)
BATCH_SIZE = 32
SEED = 123

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
    DATASET_PATH,
    validation_split=0.2,
    subset="training",
    seed=SEED,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE
)

val_ds = tf.keras.utils.image_dataset_from_directory(
    DATASET_PATH,
    validation_split=0.2,
    subset="validation",
    seed=SEED,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE
)

print("Classes:", train_ds.class_names)
num_classes = len(train_ds.class_names)
# Out:
# Found 14008 files belonging to 6 classes.
# Using 11207 files for training.
# Found 14008 files belonging to 6 classes.
# Using 2801 files for validation.
# Classes: ['buildings', 'forest', 'glacier', 'mountain', 'sea', 'street']

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(AUTOTUNE)
val_ds = val_ds.cache().prefetch(AUTOTUNE)

# %%
data_augmentation = tf.keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.2),
    layers.RandomZoom(0.2),
])

# %%
base_model = VGG16(
    weights="imagenet",
    include_top=False,
    input_shape=(224, 224, 3)
)

base_model.trainable = False
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
inputs = tf.keras.Input(shape=(224, 224, 3))

x = data_augmentation(inputs)
x = base_model(x, training=False)
x = layers.Flatten()(x)
x = layers.Dense(256, activation="relu")(x)
x = layers.Dropout(0.5)(x)

outputs = layers.Dense(num_classes, activation="softmax")(x)

model = models.Model(inputs, outputs)

# %%
model.compile(
    optimizer=Adam(learning_rate=1e-4),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

# %%
callbacks = [
    EarlyStopping(monitor="val_accuracy", patience=5, restore_best_weights=True),
    ModelCheckpoint("best_model.keras", save_best_only=True)
]

# %%
import os
from PIL import Image

dataset_path = "/content/dataset/Scene Classification/train"

bad_files = []

for root, dirs, files in os.walk(dataset_path):
    for file in files:
        file_path = os.path.join(root, file)
        try:
            img = Image.open(file_path)
            img.verify()  # checks if image is valid
        except:
            bad_files.append(file_path)

print("Bad files found:", len(bad_files))
# Out:
# Bad files found: 0

# %%
for file in bad_files:
    os.remove(file)

print("All corrupted files removed")
# Out:
# All corrupted files removed

# %%
import tensorflow as tf

IMG_SIZE = (224, 224)
BATCH_SIZE = 32

train_ds = tf.keras.utils.image_dataset_from_directory(
    train_dir,
    validation_split=0.2,
    subset="training",
    seed=123,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE
)

val_ds = tf.keras.utils.image_dataset_from_directory(
    train_dir,
    validation_split=0.2,
    subset="validation",
    seed=123,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE
)

print("Classes:", train_ds.class_names)
# Out:
# Found 14008 files belonging to 6 classes.
# Using 11207 files for training.
# Found 14008 files belonging to 6 classes.
# Using 2801 files for validation.
# Classes: ['buildings', 'forest', 'glacier', 'mountain', 'sea', 'street']

# %%
import time
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# ─── Phase 1: Feature Extraction ──────────────────────────────────────────────

model.compile(
    optimizer=Adam(learning_rate=1e-3),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

fe_callbacks = [
    EarlyStopping(
        monitor='val_accuracy',
        patience=5,
        restore_best_weights=True,
        verbose=1
    ),
    ModelCheckpoint(
        'best_fe.keras',
        monitor='val_accuracy',
        save_best_only=True,
        mode='max',
        verbose=0
    )
]

print('Phase 1 — Feature Extraction (frozen base) …')

fe_start = time.time()

history_fe = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=20,
    callbacks=fe_callbacks,
    verbose=1
)

fe_time = time.time() - fe_start

print(f'\nFeature extraction time : {fe_time:.1f} s  ({fe_time/60:.1f} min)')
# Out:
# Phase 1 — Feature Extraction (frozen base) …
# Epoch 1/20
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 92s 227ms/step - accuracy: 0.6377 - loss: 2.1295 - val_accuracy: 0.8554 - val_loss: 0.5382
# Epoch 2/20
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 118s 187ms/step - accuracy: 0.6885 - loss: 0.8945 - val_accuracy: 0.8515 - val_loss: 0.5048
# Epoch 3/20
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 82s 187ms/step - accuracy: 0.7145 - loss: 0.8318 - val_accuracy: 0.8543 - val_loss: 0.5182
# Epoch 4/20
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 65s 185ms/step - accuracy: 0.7479 - loss: 0.7022 - val_accuracy: 0.8675 - val_loss: 0.4889
# Epoch 5/20
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 65s 184ms/step - accuracy: 0.7609 - loss: 0.6997 - val_accuracy: 0.8647 - val_loss: 0.4399
# Epoch 6/20
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 66s 186ms/step - accuracy: 0.7671 - loss: 0.6783 - val_accuracy: 0.8693 - val_loss: 0.4730
# Epoch 7/20
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 67s 191ms/step - accuracy: 0.7762 - loss: 0.6460 - val_accuracy: 0.8786 - val_loss: 0.3955
# Epoch 8/20
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 67s 186ms/step - accuracy: 0.7762 - loss: 0.6329 - val_accuracy: 0.8683 - val_loss: 0.5226
# Epoch 9/20
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 80s 187ms/step - accuracy: 0.7816 - loss: 0.6122 - val_accuracy: 0.8747 - val_loss: 0.4646
# Epoch 10/20
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 65s 186ms/step - accuracy: 0.7922 - loss: 0.6120 - val_accuracy: 0.8793 - val_loss: 0.4055
# Epoch 11/20
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 88s 203ms/step - accuracy: 0.7960 - loss: 0.5865 - val_accuracy: 0.8850 - val_loss: 0.4115
# Epoch 12/20
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 80s 228ms/step - accuracy: 0.7908 - loss: 0.6117 - val_accuracy: 0.8883 - val_loss: 0.4078
# Epoch 13/20
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 71s 201ms/step - accuracy: 0.7984 - loss: 0.5940 - val_accuracy: 0.8897 - val_loss: 0.4142
# Epoch 14/20
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 65s 184ms/step - accuracy: 0.8069 - loss: 0.5882 - val_accuracy: 0.8665 - val_loss: 0.4724
# Epoch 15/20
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 64s 183ms/step - accuracy: 0.8062 - loss: 0.5779 - val_accuracy: 0.8793 - val_loss: 0.4565
# Epoch 16/20
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 65s 184ms/step - accuracy: 0.8007 - loss: 0.5938 - val_accuracy: 0.8690 - val_loss: 0.4570
# Epoch 17/20
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 65s 185ms/step - accuracy: 0.8059 - loss: 0.5841 - val_accuracy: 0.8847 - val_loss: 0.4182
# Epoch 18/20
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 65s 184ms/step - accuracy: 0.7996 - loss: 0.5924 - val_accuracy: 0.8829 - val_loss: 0.4563
# Epoch 18: early stopping
# Restoring model weights from the end of the best epoch: 13.
#
# Feature extraction time : 1329.3 s  (22.2 min)

# %%
import time
import tensorflow as tf
from tensorflow.keras.applications import VGG16
from tensorflow.keras import layers, models
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# Unfreeze base model
base_model.trainable = True

# Freeze earlier layers, train last 15 layers only
for layer in base_model.layers[:-15]:
    layer.trainable = False

# Recompile model
model.compile(
    optimizer=Adam(learning_rate=1e-5),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)
# Fine-tuning callbacks
ft_callbacks = [
    EarlyStopping(
        monitor='val_loss',
        patience=5,
        restore_best_weights=True,
        verbose=1
    ),

    ModelCheckpoint(
        'best_ft.keras',
        monitor='val_loss',
        save_best_only=True,
        mode='min',
        verbose=1
    )
]
# Train fine-tuning model
ft_start = time.time()
history_ft = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=10,
    callbacks=ft_callbacks,
    verbose=1
)
ft_time = time.time() - ft_start
print(f"\nFine-tuning time: {ft_time:.1f} sec")

# Evaluate Model
test_loss, test_acc = model.evaluate(val_ds)

print(f"\nTest Accuracy: {test_acc:.4f}")
print(f"Test Loss: {test_loss:.4f}")

# Save Final Model
model.save("final_vgg16_model.keras")

print("\nModel saved successfully.")
# Out:
# Epoch 1/10
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - accuracy: 0.8086 - loss: 0.5506
# Epoch 1: val_loss improved from None to 0.34803, saving model to best_ft.keras
#
# Epoch 1: finished saving model to best_ft.keras
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 183s 493ms/step - accuracy: 0.8164 - loss: 0.5406 - val_accuracy: 0.8968 - val_loss: 0.3480
# Epoch 2/10
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step - accuracy: 0.8461 - loss: 0.4489
# Epoch 2: val_loss improved from 0.34803 to 0.34160, saving model to best_ft.keras
#
# Epoch 2: finished saving model to best_ft.keras
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 161s 459ms/step - accuracy: 0.8501 - loss: 0.4458 - val_accuracy: 0.9007 - val_loss: 0.3416
# Epoch 3/10
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step - accuracy: 0.8633 - loss: 0.4146
# Epoch 3: val_loss improved from 0.34160 to 0.32344, saving model to best_ft.keras
#
# Epoch 3: finished saving model to best_ft.keras
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 158s 451ms/step - accuracy: 0.8653 - loss: 0.4162 - val_accuracy: 0.9050 - val_loss: 0.3234
# Epoch 4/10
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step - accuracy: 0.8760 - loss: 0.3655
# Epoch 4: val_loss improved from 0.32344 to 0.31510, saving model to best_ft.keras
#
# Epoch 4: finished saving model to best_ft.keras
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 157s 446ms/step - accuracy: 0.8744 - loss: 0.3842 - val_accuracy: 0.9050 - val_loss: 0.3151
# Epoch 5/10
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step - accuracy: 0.8851 - loss: 0.3519
# Epoch 5: val_loss improved from 0.31510 to 0.31097, saving model to best_ft.keras
#
# Epoch 5: finished saving model to best_ft.keras
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 150s 427ms/step - accuracy: 0.8825 - loss: 0.3607 - val_accuracy: 0.9057 - val_loss: 0.3110
# Epoch 6/10
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step - accuracy: 0.8879 - loss: 0.3384
# Epoch 6: val_loss did not improve from 0.31097
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 141s 402ms/step - accuracy: 0.8930 - loss: 0.3315 - val_accuracy: 0.9097 - val_loss: 0.3368
# Epoch 7/10
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - accuracy: 0.8888 - loss: 0.3364
# Epoch 7: val_loss did not improve from 0.31097
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 141s 401ms/step - accuracy: 0.8854 - loss: 0.3395 - val_accuracy: 0.9093 - val_loss: 0.3328
# Epoch 8/10
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - accuracy: 0.9073 - loss: 0.2893
# Epoch 8: val_loss did not improve from 0.31097
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 141s 401ms/step - accuracy: 0.9012 - loss: 0.2977 - val_accuracy: 0.9129 - val_loss: 0.3222
# Epoch 9/10
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - accuracy: 0.9060 - loss: 0.2887
# Epoch 9: val_loss did not improve from 0.31097
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 141s 401ms/step - accuracy: 0.9027 - loss: 0.3002 - val_accuracy: 0.9115 - val_loss: 0.3447
# Epoch 10/10
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - accuracy: 0.9049 - loss: 0.2829
# Epoch 10: val_loss did not improve from 0.31097
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 141s 401ms/step - accuracy: 0.9029 - loss: 0.2947 - val_accuracy: 0.9150 - val_loss: 0.3318
# Epoch 10: early stopping
# Restoring model weights from the end of the best epoch: 5.
#
# Fine-tuning time: 1513.4 sec
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 13s 143ms/step - accuracy: 0.9057 - loss: 0.3110
#
# Test Accuracy: 0.9057
# Test Loss: 0.3110
#
# Model saved successfully.

# %%
# ── Core Python ──────────────────────────────────────────────────────────────
import os
import random
import shutil
import time
import zipfile
from collections import Counter, defaultdict
from copy import deepcopy

# ── Data Handling & Visualization ────────────────────────────────────────────
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import seaborn as sns
from PIL import Image, UnidentifiedImageError

# ── Scikit-Learn ─────────────────────────────────────────────────────────────
from sklearn.metrics import (
    classification_report,
    confusion_matrix,
    ConfusionMatrixDisplay
)

# ── TensorFlow / Keras ──────────────────────────────────────────────
import tensorflow as tf
from tensorflow.keras import layers, models, regularizers
from tensorflow.keras.models import Model, clone_model
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.layers import (
    BatchNormalization, Conv2D, Dense, Dropout,
    Flatten, GlobalAveragePooling2D, Input, MaxPooling2D
)

# ── Reproducibility ──────────────────────────────────────────────────────────
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

print(f"TensorFlow version : {tf.__version__}")
print(f"GPU available      : {tf.config.list_physical_devices('GPU')}")

# %%
# ─── Feature Extraction vs Fine-Tuning training curves ────────────────────────
fig, axes = plt.subplots(1, 2, figsize=(14, 5))
fig.suptitle('Transfer Learning — Feature Extraction vs Fine-Tuning', fontsize=14, fontweight='bold')

colors = {'fe_tr': '#45aaf2', 'fe_vl': '#a5dff9', 'ft_tr': '#eb4d4b', 'ft_vl': '#f5b7b1'}

ax = axes[0]
ax.plot(history_fe.history['accuracy'],     label='FE — Train', color=colors['fe_tr'], lw=2, marker='o', ms=4)
ax.plot(history_fe.history['val_accuracy'], label='FE — Val',   color=colors['fe_vl'], lw=2, ls='--', marker='s', ms=4)
ax.plot(history_ft.history['accuracy'],     label='FT — Train', color=colors['ft_tr'], lw=2, marker='o', ms=4)
ax.plot(history_ft.history['val_accuracy'], label='FT — Val',   color=colors['ft_vl'], lw=2, ls='--', marker='s', ms=4)
ax.set_title('Accuracy'); ax.set_xlabel('Epoch'); ax.set_ylabel('Accuracy')
ax.set_ylim(0, 1.05); ax.legend(fontsize=9); ax.grid(True, alpha=0.4)

ax = axes[1]
ax.plot(history_fe.history['loss'],     label='FE — Train', color=colors['fe_tr'], lw=2, marker='o', ms=4)
ax.plot(history_fe.history['val_loss'], label='FE — Val',   color=colors['fe_vl'], lw=2, ls='--', marker='s', ms=4)
ax.plot(history_ft.history['loss'],     label='FT — Train', color=colors['ft_tr'], lw=2, marker='o', ms=4)
ax.plot(history_ft.history['val_loss'], label='FT — Val',   color=colors['ft_vl'], lw=2, ls='--', marker='s', ms=4)
ax.set_title('Loss'); ax.set_xlabel('Epoch'); ax.set_ylabel('Loss')
ax.legend(fontsize=9); ax.grid(True, alpha=0.4)

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

def evaluate_model(model, dataset, class_names, title="Model Evaluation"):

    y_true = []
    y_pred = []

    for images, labels in dataset:
        preds = model.predict(images, verbose=0)
        preds = np.argmax(preds, axis=1)

        y_true.extend(labels.numpy())
        y_pred.extend(preds)

    # Classification report
    print("\n", title)
    print(classification_report(y_true, y_pred, target_names=class_names))

    # Confusion matrix
    cm = confusion_matrix(y_true, y_pred)

    plt.figure(figsize=(8,6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=class_names,
                yticklabels=class_names)

    plt.title(title)
    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.show()

    return y_true, y_pred

# %%
import tensorflow as tf

DATASET_PATH = "/content/drive/MyDrive/AI and ML/Data/Scene Classification/train"

train_ds = tf.keras.utils.image_dataset_from_directory(
    DATASET_PATH,
    validation_split=0.2,
    subset="training",
    seed=123,
    image_size=(224, 224),
    batch_size=32
)

val_ds = tf.keras.utils.image_dataset_from_directory(
    DATASET_PATH,
    validation_split=0.2,
    subset="validation",
    seed=123,
    image_size=(224, 224),
    batch_size=32
)

class_names = train_ds.class_names  # FIX HERE

print("Classes:", class_names)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

def evaluate_model(model, dataset, class_names, title="Model Evaluation"):

    y_true = []
    y_pred = []

    for images, labels in dataset:
        preds = model.predict(images, verbose=0)
        preds = np.argmax(preds, axis=1)

        y_true.extend(labels.numpy())
        y_pred.extend(preds)

    print("\n", title)
    print(classification_report(y_true, y_pred, target_names=class_names))

    cm = confusion_matrix(y_true, y_pred)

    plt.figure(figsize=(8,6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=class_names,
                yticklabels=class_names)

    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.title(title)
    plt.show()

    return y_true, y_pred

# %%
tl_y_true, tl_y_pred = evaluate_model(
    model,
    val_ds,
    class_names,
    title='VGG16 Fine-Tuned (Validation Set)'
)

# %%
tl_y_true, tl_y_pred = evaluate_model(
    model,          # correct model name
    val_ds,         # correct dataset
    class_names,    # correct variable name
    title='MobileNetV2 Fine-Tuned (Validation Set)'
)

# %%
import numpy as np
import matplotlib.pyplot as plt

# ─── Inference on validation samples ──────────────────────────────────────

sample_imgs, sample_labels = next(iter(val_ds))

preds = model.predict(sample_imgs, verbose=0)
pred_classes = np.argmax(preds, axis=1)

fig, axes = plt.subplots(2, 6, figsize=(18, 6))
fig.suptitle('Model — Inference on Validation Samples', fontsize=14, fontweight='bold')

for i, ax in enumerate(axes.flat):
    if i >= len(sample_imgs):
        ax.axis('off')
        continue

    ax.imshow(np.clip(sample_imgs[i].numpy() / 255.0, 0, 1))

    true_lbl = class_names[int(sample_labels[i].numpy())]
    pred_lbl = class_names[pred_classes[i]]

    ax.set_title(
        f'T: {true_lbl}\nP: {pred_lbl}',
        fontsize=8,
        color='green' if true_lbl == pred_lbl else 'red'
    )

    ax.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ## Final Comparison — All Models

# %%
import numpy as np

y_true = []
y_pred = []

for images, labels in val_ds:
    preds = model.predict(images, verbose=0)
    preds = np.argmax(preds, axis=1)

    y_true.extend(labels.numpy())
    y_pred.extend(preds)

# %%
from sklearn.metrics import accuracy_score, f1_score

acc = accuracy_score(y_true, y_pred)
f1 = f1_score(y_true, y_pred, average='macro')

print("Model Performance")
print("Accuracy:", acc)
print("Macro F1:", f1)

# %%
import matplotlib.pyplot as plt

names = ["VGG16 Fine-Tuned"]

accs = [acc]
f1s = [f1]

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 4))

ax1.bar(names, accs)
ax1.set_title("Accuracy")
ax1.set_ylim(0, 1)

ax2.bar(names, f1s)
ax2.set_title("Macro F1")
ax2.set_ylim(0, 1)

plt.tight_layout()
plt.show()

# %%
import numpy as np

def get_preds(model, dataset):
    y_true, y_pred = [], []

    for images, labels in dataset:
        preds = model.predict(images, verbose=0)
        preds = np.argmax(preds, axis=1)

        y_true.extend(labels.numpy())
        y_pred.extend(preds)

    return np.array(y_true), np.array(y_pred)

# %%
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# Function to get predictions

def get_preds(model, dataset):

    y_true = []
    y_pred = []

    for images, labels in dataset:

        # Predict probabilities
        preds = model.predict(images, verbose=0)

        # Convert probabilities to class labels
        preds = np.argmax(preds, axis=1)

        # Store results
        y_true.extend(labels.numpy())
        y_pred.extend(preds)

    return np.array(y_true), np.array(y_pred)

# Get Predictions from Your Trained Model
y_true, y_pred = get_preds(model, val_ds)

# Accuracy
acc = accuracy_score(y_true, y_pred)
print(f"\nValidation Accuracy: {acc:.4f}")

# Classification Report
class_names = train_ds.class_names
print("\nClassification Report:\n")
print(
    classification_report(
        y_true,
        y_pred,
        target_names=class_names
    )
)

# Confusion Matrix
cm = confusion_matrix(y_true, y_pred)
print("\nConfusion Matrix:\n")
print(cm)

# %% [markdown]
# ---
# ## Conclusion
#
# 1. **Baseline CNN** — good starting point, mild overfitting without regularisation.
# 2. **Deeper CNN (Adam)** — BatchNorm + Dropout + L2 reduces overfitting; confirmed by ablation study.
# 3. **Adam vs SGD** — Adam converges faster; SGD can match with more epochs and Nesterov momentum.
# 4. **MobileNetV2** — highest accuracy with least training effort; ImageNet features transfer well to natural scenes.
#
# ### Future Work
# - EfficientNetV2 / ConvNeXt for better accuracy-efficiency trade-off
# - Test-time augmentation (TTA)
# - Class-weighted loss for imbalance
# - Hyperparameter search (Keras Tuner / Optuna)
# - Gradio / Streamlit deployment

# %% [markdown]
# ---
# ## Final Evaluation on Unseen Test Set
# Test set was kept completely unseen during training. Now evaluating all models on it.

# %%
# ── Build test dataset pipeline ──────────────────────────────────
test_ds_raw = tf.keras.utils.image_dataset_from_directory(
    test_dir,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    shuffle=False
)

# Normalise for scratch models
test_ds = (test_ds_raw
           .map(norm, num_parallel_calls=tf.data.AUTOTUNE)
           .prefetch(tf.data.AUTOTUNE))

# Preprocess for MobileNetV2
tl_test_ds = (test_ds_raw
              .map(lambda x, y: (mobilenet_preprocess(x), y),
                   num_parallel_calls=tf.data.AUTOTUNE)
              .prefetch(tf.data.AUTOTUNE))

print("Test datasets ready.")
print(f"Test batches : {len(test_ds)}")

# %%
# ── Evaluate all models on test set ─────────────────────────────
print("=" * 55)
print("  FINAL TEST SET EVALUATION — All Models")
print("=" * 55)

test_base_yt,  test_base_yp  = run_evaluation(baseline_model, test_ds,    CLASS_NAMES, 'Baseline CNN (Test Set)')
test_deep_yt,  test_deep_yp  = run_evaluation(deeper_model,   test_ds,    CLASS_NAMES, 'Deeper CNN Adam (Test Set)')
test_sgd_yt,   test_sgd_yp   = run_evaluation(sgd_model,      test_ds,    CLASS_NAMES, 'Deeper CNN SGD (Test Set)')
test_tl_yt,    test_tl_yp    = run_evaluation(tl_model,       tl_test_ds, CLASS_NAMES, 'MobileNetV2 Fine-Tuned (Test Set)')

# %%
# ── Final test set comparison bar chart ─────────────────────────
from sklearn.metrics import accuracy_score, f1_score

test_results = [
    ('Baseline CNN',          test_base_yt,  test_base_yp),
    ('Deeper CNN (Adam)',     test_deep_yt,  test_deep_yp),
    ('Deeper CNN (SGD)',      test_sgd_yt,   test_sgd_yp),
    ('MobileNetV2 Fine-Tune', test_tl_yt,    test_tl_yp),
]

test_names, test_accs, test_f1s = [], [], []
print(f"{'Model':<26}  {'Test Acc':>10}  {'Macro F1':>10}")
print('-' * 52)
for name, yt, yp in test_results:
    a = accuracy_score(yt, yp); f = f1_score(yt, yp, average='macro')
    print(f"{name:<26}  {a:>10.4f}  {f:>10.4f}")
    test_names.append(name); test_accs.append(a); test_f1s.append(f)

fig, (a1, a2) = plt.subplots(1, 2, figsize=(12, 4))
fig.suptitle('All Models — Final TEST SET Performance', fontsize=13, fontweight='bold')
colors = ['steelblue', 'darkorange', 'seagreen', 'crimson']
for ax, vals, lbl in zip([a1, a2], [test_accs, test_f1s], ['Test Accuracy', 'Macro F1']):
    ax.bar(test_names, vals, color=colors, edgecolor='black')
    ax.set_title(lbl); ax.set_ylim(0, 1.0)
    ax.set_xticklabels(test_names, rotation=15, ha='right', fontsize=9)
    for i, v in enumerate(vals):
        ax.text(i, v + 0.01, f'{v:.3f}', ha='center', fontsize=9)
plt.tight_layout(); plt.show()

print("\nMobileNetV2 typically achieves highest test accuracy due to ImageNet pretraining.")
